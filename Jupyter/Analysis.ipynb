# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1000 Epoch | Mutacao 1 gene | 1% chance mutação | 50/50 distribuição pai/filho | mutação entre os 100 melhores
#dfRobby = pd.read_csv('RobbyWorld_2018-11-20_14-51-38.csv')

# 200 Epoch | Mutacao 1 gene | 5% chance mutação | 50/50 distribuição pai/filho | mutação entre os 100 melhores
# 5 avg best reward. -15 avg reward todos
#dfRobby = pd.read_csv('RobbyWorld_2018-11-20_15-13-19.csv')

# 60 Epoch | Mutacao 40 gene | 5% chance mutação | 50/50 distribuição pai/filho | mutação entre os 100 melhores
# 2 avg best reward. -10 avg reward todos
#dfRobby = pd.read_csv('RobbyWorld_2018-11-20_15-20-13.csv')

# 60 Epoch | Mutacao 40 gene | 10% chance mutação | 50/50 distribuição pai/filho | mutação entre os 100 melhores
# 2 avg best reward. -40 avg reward todos
#dfRobby = pd.read_csv('RobbyWorld_2018-11-20_15-26-40.csv')

# 60 Epoch | Mutacao 121 gene | 1% chance mutação | 50/50 distribuição pai/filho | mutação entre os 100 melhores
# -5 avg best reward. -45 avg reward todos
#dfRobby = pd.read_csv('RobbyWorld_2018-11-20_15-32-41.csv')

# 60 Epoch | Mutacao 121 gene | 10% chance mutação | 50/50 distribuição pai/filho | mutação entre os 100 melhores
# 2 avg best reward. -35 avg reward todos
#dfRobby = pd.read_csv('RobbyWorld_2018-11-20_15-38-35.csv')

# 60 Epoch | Mutacao 121 gene | 20% chance mutação | 50/50 distribuição pai/filho | mutação entre os 100 melhores
# 1 avg best reward. -75 avg reward todos
#dfRobby = pd.read_csv('RobbyWorld_2018-11-20_15-44-09.csv')

# 60 Epoch | Mutacao 15 gene | 20% chance mutação | 50/50 distribuição pai/filho | mutação entre os 100 melhores
# 0 avg best reward. -75 avg reward todos
#dfRobby = pd.read_csv('RobbyWorld_2018-11-20_15-49-29.csv')

# 60 Epoch | Mutacao 15 gene | 5% chance mutação | 50/50 distribuição pai/filho | mutação entre os 100 melhores
#  1 avg best reward. -12 avg reward todos
#dfRobby = pd.read_csv('RobbyWorld_2018-11-20_15-55-35.csv')

# 60 Epoch | Mutacao 20 gene | 2% chance mutação | 50/50 distribuição pai/filho | mutação entre os 100 melhores
#  2.5 avg best reward. -10 avg reward todos
#dfRobby = pd.read_csv('RobbyWorld_2018-11-20_16-02-14.csv')

# 60 Epoch | Mutacao 60 gene | 2% chance mutação | 50/50 distribuição pai/filho | mutação entre os 100 melhores
#  4 avg best reward.  -10 avg reward todos
#dfRobby = pd.read_csv('RobbyWorld_2018-11-20_16-09-28.csv')

# 60 Epoch | Mutacao 60 gene | 2% chance mutação | 50/50 distribuição pai/filho | mutação entre os 100 melhores
#   avg best reward.   avg reward todos
#dfRobby = pd.read_csv('RobbyWorld_2018-11-20_17-44-19.csv')

#dfRobby

# %%
#Nova implementação do codigo

dfRobby = pd.read_csv('RobbyWorld_2018-11-26_01-52-41.csv')
dfRobby
# Out:
#     ElapsedTime  Epoch                                            BestDNA  \
# 0      0.020000      1                                                 -1
# 1      0.040000      2  2422222350254035033202620021135210266361520644...
# 2      0.140000      3  0324050513211110400240434523650604330000213233...
# 3      0.240000      4  0240464234616224236644124366256610533600403121...
# 4      0.340000      5  3321222663650424432545504606121444213006541250...
# 5      0.440000      6  3533432506131344610165565553412202052665556506...
# 6      0.540000      7  3533432506131344610165565553412202052665556506...
# 7      0.640000      8  0240464234616224236644124366256610533600403121...
# 8      0.740000      9  3235141505530106030064051102432024061663532161...
# 9      0.840000     10  1035244160360615112206336431416462644635624026...
# 10     0.940000     11  6650136263404150133055602611463051416066506661...
# 11     1.040000     12  3533432506131344610165565553412202052665556506...
# ...

# %%
dfRobby.plot(x='Epoch', y=['RewardOfBestDNA'], figsize=(20,10), grid=True, title='Reward obtained by the best bot per Epoch')

# %%
dfRobby.plot(x='Epoch', y=['AvgRewardCurEpoch'], figsize=(20,10), grid=True, title='Average reward of all bots per epoch')

# %%
size = len(originalList)
print("size", size)
newList = originalList[0: int(0.5*size)]

string = ""
for a in originalList:
    string += str(a)

print(string)


string = ""
for a in newList:
    string += str(a)
print("len", len(newList))
print(string)

newList = originalList[int(0.5*size): size]
string = ""
for a in newList:
    string += str(a)
print("len", len(newList))
print(string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e6a1b07d856f> in <module>()
# ----> 1 size = len(originalList)
#       2 print("size", size)
#       3 newList = originalList[0: int(0.5*size)]
#       4
#       5 string = ""
#
# NameError: name 'originalList' is not defined
